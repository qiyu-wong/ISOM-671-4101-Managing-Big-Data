# %%
import pandas as pd
####### Standardize numeric columns
# read in the dataset and check data types
df = pd.read_csv("C:\\Users\\dongh\\Downloads\\MBD project\\merged.csv")
df.dtypes
# Out:
# Unnamed: 0                        int64
# State                            object
# Sex Ratio                       float64
# MedianAge                       float64
# efficiency of health systems    float64
# 2019 Visitation                 float64
# Date                             object
# Type                             object
# Gini                            float64
# ICU Beds                          int64
# GDP                              object
# Hospitals                         int64
# Region                           object
# Life Expectancy                 float64
# Population, 2019                  int64
# pop per km2                     float64
# outDegree                       float64
# inDegree                        float64
# pagerank                        float64
# dtype: object

# %%
df
# Out:
#     Unnamed: 0             State  Sex Ratio  MedianAge  \
# 0            0        California     0.9751       36.3
# 1            1          Colorado     0.9948       36.6
# 2            2           Florida     0.9422       41.9
# 3            3           Georgia     0.9276       36.5
# 4            4            Hawaii     0.9546       38.9
# 5            5          Illinois     0.9550       37.9
# 6            6     Massachusetts     0.9437       39.4
# 7            7          Michigan     0.9588       39.7
# 8            8    North Carolina     0.9285       38.6
# 9            9        New Jersey     0.9467       39.8
# 10          10            Nevada     0.9881       37.9
# 11          11          New York     0.9376       38.7
# 12          12             Texas     0.9696       34.4
# 13          13          Virginia     0.9366       38.1
# 14          14        Washington     0.9835       37.6
# 15          15           Alberta     1.0114       37.5
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Sex Ratio  MedianAge  efficiency of health systems  \
# count   21.000000  21.000000  21.000000                     21.000000
# mean    10.000000   0.967243  38.938095                      0.850286
# std      6.204837   0.028044   2.466065                      0.019905
# min      0.000000   0.927600  34.400000                      0.838000
# 25%      5.000000   0.943700  37.600000                      0.838000
# 50%     10.000000   0.958900  38.600000                      0.838000
# 75%     15.000000   0.988100  39.800000                      0.881000
# max     20.000000   1.024100  45.000000                      0.881000
#
#        2019 Visitation       Gini     ICU Beds   Hospitals  Life Expectancy  \
# count        21.000000  21.000000    21.000000   21.000000        21.000000
# mean       3134.439048   0.432310  2097.428571  119.809524        80.219048
# std        3530.384851   0.082237  2091.414415  125.145363         1.543573
# ...
